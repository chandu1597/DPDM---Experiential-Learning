# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score,f1_score,recall_score

# %%
empdata = pd.read_csv("C:/Data/wholedata.csv")

# %%
empdata.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0           1               3                  3                      3.0
# 1           2               2                  4                      3.0
# 2           3               3                  3                      2.0
# 3           4               2                  3                      4.0
# 4           5               3                  3                      4.0
#
#    JobSatisfaction  WorkLifeBalance  Age Attrition     BusinessTravel  \
# 0              4.0              2.0   51        No      Travel_Rarely
# 1              2.0              4.0   31       Yes  Travel_Frequently
# 2              2.0              1.0   32        No  Travel_Frequently
# 3              4.0              3.0   38        No         Non-Travel
# 4              1.0              3.0   32        No      Travel_Rarely
#
#                Department  ...  NumCompaniesWorked  Over18 PercentSalaryHike  \
# ...

# %% [raw]
# Now, we will check for any null values in our dataset.

# %%
sns.heatmap(empdata.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap shows there are a lot of null values. Next we will remove all the null values to get a better picture of the data.

# %%
empdata.isnull().sum()
# Out:
# EmployeeID                 0
# JobInvolvement             0
# PerformanceRating          0
# EnvironmentSatisfaction    0
# JobSatisfaction            0
# WorkLifeBalance            0
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
empdata= empdata.dropna()

# %%
empdata
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0              1               3                  3                      3.0
# 1              2               2                  4                      3.0
# 2              3               3                  3                      2.0
# 3              4               2                  3                      4.0
# 4              5               3                  3                      4.0
# ...          ...             ...                ...                      ...
# 4404        4405               2                  3                      3.0
# 4405        4406               3                  3                      4.0
# 4406        4407               2                  3                      4.0
# 4407        4408               3                  4                      1.0
# 4408        4409               2                  3                      4.0
#
# ...

# %%
empdata.describe()
# Out:
#         EmployeeID  JobInvolvement  PerformanceRating  \
# count  4300.000000     4300.000000        4300.000000
# mean   2211.695116        2.728837           3.153953
# std    1272.117692        0.710769           0.360946
# min       1.000000        1.000000           3.000000
# 25%    1110.750000        2.000000           3.000000
# 50%    2215.500000        3.000000           3.000000
# 75%    3314.250000        3.000000           3.000000
# max    4409.000000        4.000000           4.000000
#
#        EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance          Age  \
# count              4300.000000      4300.000000      4300.000000  4300.000000
# mean                  2.723953         2.724884         2.761163    36.926977
# std                   1.093802         1.101875         0.707800     9.146517
# min                   1.000000         1.000000         1.000000    18.000000
# 25%                   2.000000         2.000000         2.000000    30.000000
# ...

# %%
from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()

for i in empdata.columns:
    if isinstance(empdata[i][0],str):
        empdata[i] = encoder.fit_transform(empdata[i])

# %%
empdata
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0              1               3                  3                      3.0
# 1              2               2                  4                      3.0
# 2              3               3                  3                      2.0
# 3              4               2                  3                      4.0
# 4              5               3                  3                      4.0
# ...          ...             ...                ...                      ...
# 4404        4405               2                  3                      3.0
# 4405        4406               3                  3                      4.0
# 4406        4407               2                  3                      4.0
# 4407        4408               3                  4                      1.0
# 4408        4409               2                  3                      4.0
#
# ...

# %%
empdata.Attrition.value_counts()
# Out:
# 0    3605
# 1     695
# Name: Attrition, dtype: int64

# %% [markdown]
# We can see from the above mentioned syntax that the dataset is HIGHLY IMBALANCED. The majority class (No attrition) exceeds the minority class(Attrition) by approximately 5 times.

# %%
import matplotlib.pyplot as plt
labels = 'Majority', 'Minority'
sizes = [3605,695]
colors = ['gold''lightcoral']
explode = (0.1, 0)

# %%
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2342b303130>,
# ...
#  [Text(-0.5834747157944258, -1.0485977570205909, 'Majority'),
#   Text(0.5348517778138535, 0.9612146356404279, 'Minority')],
#  [Text(-0.34036025088008165, -0.6116820249286781, '83.8%'),
#   Text(0.291737333353011, 0.524298892167506, '16.2%')])

# %%
sns.countplot(x='Attrition',data=empdata)  
plt.show()

# %% [markdown]
# Let's say we now have to plot some graphs. The manager of the the company wants to see which department has the highest attrition rate.

# %%
empdata.Department.value_counts()
# Out:
# 1    2807
# 2    1307
# 0     186
# Name: Department, dtype: int64

# %%
import seaborn as sns  
import pandas as pd     
 
chart=sns.countplot(x='Department',hue='Attrition',data=empdata)  
chart.labels=['sales','hr','rd']
plt.show()
