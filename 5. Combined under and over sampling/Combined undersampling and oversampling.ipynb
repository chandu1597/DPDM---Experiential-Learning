# %%
## Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=c86d3a21029b2b312ac80b11416adecde596ed6e6e82022e514bb804c7c335f7
#   Stored in directory: c:\users\chand\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %%
## Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install matplotlib

# %% [markdown]
# # 1. Reading data and Data preparation before resampling

# %%
# Reading data
import pandas as pd

emp_attr_data = pd.read_csv('employee attrition.csv',sep=',')
emp_attr_data.head()
# Out:
#    EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0           1               3                  3                      3.0
# 1           2               2                  4                      3.0
# 2           3               3                  3                      2.0
# 3           4               2                  3                      4.0
# 4           5               3                  3                      4.0
#
#    JobSatisfaction  WorkLifeBalance  Age Attrition     BusinessTravel  \
# 0              4.0              2.0   51        No      Travel_Rarely
# 1              2.0              4.0   31       Yes  Travel_Frequently
# 2              2.0              1.0   32        No  Travel_Frequently
# 3              4.0              3.0   38        No         Non-Travel
# 4              1.0              3.0   32        No      Travel_Rarely
#
#                Department  ...  NumCompaniesWorked  Over18 PercentSalaryHike  \
# ...

# %%
len(emp_attr_data.index)
# Out:
# 4410

# %%
# Removing null values
empdata = emp_attr_data.dropna()
len(empdata.index)
# Out:
# 4300

# %%
empdata
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0              1               3                  3                      3.0
# 1              2               2                  4                      3.0
# 2              3               3                  3                      2.0
# 3              4               2                  3                      4.0
# 4              5               3                  3                      4.0
# ...          ...             ...                ...                      ...
# 4404        4405               2                  3                      3.0
# 4405        4406               3                  3                      4.0
# 4406        4407               2                  3                      4.0
# 4407        4408               3                  4                      1.0
# 4408        4409               2                  3                      4.0
#
# ...

# %%
# understanding the imbalance in attrition column
empdata['Attrition'].describe()
# Out:
# count     4300
# unique       2
# top         No
# freq      3605
# Name: Attrition, dtype: object

# %%
# converting all categorical variables to numeric to get more accuracy

from sklearn import preprocessing
encoder = preprocessing.LabelEncoder()

for i in empdata.columns:
    if isinstance(empdata[i][0],str):
        empdata[i] = encoder.fit_transform(empdata[i])
# Out:
# <ipython-input-7-884936ced8dc>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empdata[i] = encoder.fit_transform(empdata[i])

# %%
# Further skewing the data by making minority class from 695 to 95 values
empdata = empdata[empdata['Attrition']==0].append(empdata[empdata['Attrition']==1].head(95))
empdata
# Out:
#      EmployeeID  JobInvolvement  PerformanceRating  EnvironmentSatisfaction  \
# 0             1               3                  3                      3.0
# 2             3               3                  3                      2.0
# 3             4               2                  3                      4.0
# 4             5               3                  3                      4.0
# 5             6               3                  3                      3.0
# ..          ...             ...                ...                      ...
# 542         543               3                  3                      1.0
# 543         544               3                  3                      4.0
# 555         556               3                  3                      1.0
# 570         571               4                  3                      3.0
# 571         572               2                  3                      1.0
#
# ...

# %%
columns = empdata.columns.tolist()
columns = [c for c in columns if c not in ["Attrition"]]
target = "Attrition"
X = empdata[columns]
y = empdata[target]
print(X.shape)
print(y.shape)
# Out:
# (3700, 28)
# (3700,)

# %%
# summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 3605, 1: 95})

# %%
# evaluates a decision tree model on the imbalanced dataset
from numpy import mean
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

# define model
model = DecisionTreeClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.639

# %% [markdown]
# # 2.Manual combinations

# %% [markdown]
# ### 2.1 Random undersampling and oversampling

# %%
# # Install a pip package in the current Jupyter kernel
# import sys
# !{sys.executable} -m pip install imbalanced-learn

# %%
# combination of random oversampling and undersampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler


# define model
model = DecisionTreeClassifier()

# define resampling
over = RandomOverSampler(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=0.5)

# define pipeline
pipeline = Pipeline(steps=[('o', over), ('u', under), ('m', model)])

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.738

# %% [markdown]
# ### 2.2 Random undersampling and SMOTE

# %%
# combination of SMOTE and random undersampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# define model
model = DecisionTreeClassifier()

# define pipeline
over = SMOTE(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=0.5)
steps = [('o', over), ('u', under), ('m', model)]
pipeline = Pipeline(steps=steps)

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.776

# %% [markdown]
# # 3.Predefined combinations

# %% [markdown]
# ### 3.1 Tomek Links undersampling and SMOTE

# %%
# combined SMOTE and Tomek Links resampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks

# define model
model = DecisionTreeClassifier()

# define resampling
resample = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))

# define pipeline
pipeline = Pipeline(steps=[('r', resample), ('m', model)])

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.695

# %% [markdown]
# ### 3.2 SMOTE and Edited Nearest Neighbors Undersampling

# %%
# combined SMOTE and Edited Nearest Neighbors resampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTEENN

# define model
model = DecisionTreeClassifier()

# define resampling
resample = SMOTEENN()

# define pipeline
pipeline = Pipeline(steps=[('r', resample), ('m', model)])

# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.826
